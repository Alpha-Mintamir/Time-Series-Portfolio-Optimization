# %%
import pandas as pd
import sys 
import os
sys.path.append(os.path.abspath('../scripts'))

# %%
from EDA import *

# %%
tsla_df = pd.read_csv('../data/TSLA.csv')
spy_df = pd.read_csv('../data/SPY.csv')
bnd_df = pd.read_csv('../data/BND.csv')

# %% [markdown]
# # Exploratory Data Analysis (EDA) of the three datasets

# %% [markdown]
# ## 1. Tesla Stock Data

# %%
tsla_eda = StockEDA(tsla_df)
tsla_eda.plot_closing_price()
tsla_eda.plot_daily_percentage_change()
tsla_eda.analyze_volatility(window=20)
outliers = tsla_eda.detect_outliers()
extreme_returns = tsla_eda.analyze_extreme_returns(threshold=0.05)
# Out:
# 2024-11-10 16:47:12,160 - INFO - StockEDA class initialized with DataFrame.
# 2024-11-10 16:47:12,163 - INFO - Plotting closing price over time.
# 2024-11-10 16:47:12,828 - INFO - Calculating and plotting daily percentage change.
# 2024-11-10 16:47:13,560 - INFO - Analyzing volatility with a 20-day rolling window.
# 2024-11-10 16:47:14,320 - INFO - Detecting outliers based on Z-score.
# 2024-11-10 16:47:14,329 - INFO - Found 0 outliers.
# 2024-11-10 16:47:14,331 - INFO - Analyzing extreme returns with a threshold of 0.05.
# 2024-11-10 16:47:14,336 - INFO - Found 299 days with extreme returns.

# %% [markdown]
# ## 3. SPY Stock Data

# %%
spy_eda = StockEDA(spy_df)
spy_eda.plot_closing_price()
spy_eda.plot_daily_percentage_change()
spy_eda.analyze_volatility(window=20)
outliers = spy_eda.detect_outliers()
extreme_returns = spy_eda.analyze_extreme_returns(threshold=0.05)
# Out:
# 2024-11-10 16:48:47,615 - INFO - StockEDA class initialized with DataFrame.
# 2024-11-10 16:48:47,620 - INFO - Plotting closing price over time.
# 2024-11-10 16:48:48,550 - INFO - Calculating and plotting daily percentage change.
# 2024-11-10 16:48:49,903 - INFO - Analyzing volatility with a 20-day rolling window.
# 2024-11-10 16:48:51,050 - INFO - Detecting outliers based on Z-score.
# 2024-11-10 16:48:51,057 - INFO - Found 0 outliers.
# 2024-11-10 16:48:51,059 - INFO - Analyzing extreme returns with a threshold of 0.05.
# 2024-11-10 16:48:51,064 - INFO - Found 13 days with extreme returns.
