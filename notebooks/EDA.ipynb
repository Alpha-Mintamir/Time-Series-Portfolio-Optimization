# %%
import pandas as pd
import sys 
import os
sys.path.append(os.path.abspath('../scripts'))

# %%
from EDA import *

# %%
tsla_df = pd.read_csv('../data/TSLA.csv')
spy_df = pd.read_csv('../data/SPY.csv')
bnd_df = pd.read_csv('../data/BND.csv')

# %% [markdown]
# # Exploratory Data Analysis (EDA) of the three datasets

# %% [markdown]
# ## 1. Tesla Stock Data

# %%
tsla_eda = StockEDA(tsla_df)
tsla_eda.plot_closing_price()
tsla_eda.plot_daily_percentage_change()
tsla_eda.analyze_volatility(window=20)
outliers = tsla_eda.detect_outliers()
extreme_returns = tsla_eda.analyze_extreme_returns(threshold=0.05)
# Out:
# 2024-11-11 06:00:16,031 - INFO - StockEDA class initialized with DataFrame.
# 2024-11-11 06:00:16,036 - INFO - Plotting closing price over time.
# 2024-11-11 06:00:16,649 - INFO - Calculating and plotting daily percentage change.
# 2024-11-11 06:00:17,223 - INFO - Analyzing volatility with a 20-day rolling window.
# 2024-11-11 06:00:17,876 - INFO - Detecting outliers based on Z-score.
# 2024-11-11 06:00:17,892 - INFO - Found 0 outliers.
# 2024-11-11 06:00:17,895 - INFO - Analyzing extreme returns with a threshold of 0.05.
# 2024-11-11 06:00:17,902 - INFO - Found 299 days with extreme returns.

# %% [markdown]
# ## 2. SPY Stock Data

# %%
spy_eda = StockEDA(spy_df)
spy_eda.plot_closing_price()
spy_eda.plot_daily_percentage_change()
spy_eda.analyze_volatility(window=20)
outliers = spy_eda.detect_outliers()
extreme_returns = spy_eda.analyze_extreme_returns(threshold=0.05)
# Out:
# 2024-11-11 06:00:17,963 - INFO - StockEDA class initialized with DataFrame.
# 2024-11-11 06:00:17,969 - INFO - Plotting closing price over time.
# 2024-11-11 06:00:18,665 - INFO - Calculating and plotting daily percentage change.
# 2024-11-11 06:00:19,525 - INFO - Analyzing volatility with a 20-day rolling window.
# 2024-11-11 06:00:20,705 - INFO - Detecting outliers based on Z-score.
# 2024-11-11 06:00:20,712 - INFO - Found 0 outliers.
# 2024-11-11 06:00:20,715 - INFO - Analyzing extreme returns with a threshold of 0.05.
# 2024-11-11 06:00:20,725 - INFO - Found 13 days with extreme returns.

# %% [markdown]
# ## 3. BND Stock Data

# %%
bnd_eda = StockEDA(bnd_df)
bnd_eda.plot_closing_price()
bnd_eda.plot_daily_percentage_change()
bnd_eda.analyze_volatility(window=20)
outliers = bnd_eda.detect_outliers()
extreme_returns = bnd_eda.analyze_extreme_returns(threshold=0.05)
# Out:
# 2024-11-11 06:00:59,751 - INFO - StockEDA class initialized with DataFrame.
# 2024-11-11 06:00:59,754 - INFO - Plotting closing price over time.
# 2024-11-11 06:01:00,425 - INFO - Calculating and plotting daily percentage change.
# 2024-11-11 06:01:00,924 - INFO - Analyzing volatility with a 20-day rolling window.
# 2024-11-11 06:01:01,998 - INFO - Detecting outliers based on Z-score.
# 2024-11-11 06:01:02,008 - INFO - Found 0 outliers.
# 2024-11-11 06:01:02,012 - INFO - Analyzing extreme returns with a threshold of 0.05.
# 2024-11-11 06:01:02,017 - INFO - Found 1 days with extreme returns.
